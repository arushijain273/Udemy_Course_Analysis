# %%
import pandas as pd

# %%
data = pd.read_csv("udemy_courses.csv")

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
#  12  year                 3678 non-null   int64
# dtypes: bool(1), float64(1), int64(6), object(5)
# memory usage: 348.5+ KB

# %% [markdown]
# # Unique Subjects

# %%
data.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# ## which subject has maximum number of courses

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
# which level has maximum courses

# %%
data.level.value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
## which courses are free of cost

# %%
data[data.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
## which courses are paid

# %%
data[data.is_paid == True]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
## which are the top selling courses? which have the maximum subscribers

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#          published_timestamp           subject  year
# 0  2017-01-18 20:58:58+00:00  Business Finance  2017
# 1  2017-03-09 16:34:20+00:00  Business Finance  2017

# %%
data.sort_values("num_subscribers", ascending = False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1569     726314       Create Beautiful Image Maps for Your Website
# 1473     185526                             MicroStation - Células
# 1472     181268               Photoshop: Creando elemental de aire
# 1471     188584                        Letras en Adobe Illustrator
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
## which are least selling courses

# %%
data.sort_values('num_subscribers', ascending = True)
# Out:
#       course_id                                       course_title  \
# 885     1032648                               beginning accounting
# 456     1247992  Introduction to Project Management for Finance...
# 457     1251582              Best Practices in Corporate Budgeting
# 458     1258666                Financial Statement Auditing Cycles
# 459     1168172       Case studies on credit appraisal for bankers
# ...         ...                                                ...
# 3232     764164              The Complete Web Developer Course 2.0
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3230     625204                         The Web Developer Bootcamp
# 3032      59014                     Coding for Entrepreneurs Basic
# 2827      41295               Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 885         https://www.udemy.com/beginning_accounting/     True     20
# ...

# %%
## courses of graphic design which have price below 100

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#          published_timestamp           subject  year
# 0  2017-01-18 20:58:58+00:00  Business Finance  2017
# 1  2017-03-09 16:34:20+00:00  Business Finance  2017

# %%
data[(data.subject =='Graphic Design') & (data.price < 100)]
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# ...

# %%
## list all courses which have python

# %%
len(data[data.course_title.str.contains('Python')])
# Out:
# 29

# %%
## which courses were published in 2015

# %%
data.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# year                     int64
# dtype: object

# %%
data.published_timestamp = pd.to_datetime(data.published_timestamp)

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# year                                 int64
# dtype: object

# %%
data['year'] = data.published_timestamp.dt.year

# %%
data.to_csv("udemy_courses.csv", index = False)

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# year                                 int64
# dtype: object

# %%
data[data.year == 2015]
# Out:
#       course_id                                       course_title  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 17       564966  The Complete Chart Pattern Trading Course: A P...
# ...         ...                                                ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3669     679992                  Building Better APIs with GraphQL
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3675     635248                      Learn and Build using Polymer
#
#                                                     url  is_paid  price  \
# 7     https://www.udemy.com/trading-chart-patterns-f...     True     95
# ...

# %%
## maximum number of subscribers for each level of courses

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level')['num_subscribers'].min()
# Out:
# level
# All Levels            0
# Beginner Level        0
# Expert Level          1
# Intermediate Level    0
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                                                                   url  \
# level
# All Levels          https://www.udemy.com/zombie-apocalypse-photos...
# Beginner Level                        https://www.udemy.com/zprzqgfl/
# Expert Level        https://www.udemy.com/working-capital-manageme...
# Intermediate Level           https://www.udemy.com/youtubedownloader/
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# ...

# %%
##total revenue every year

# %%
data["revenue"] = data[data.num_subscribers * data.price]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-393fde314a97> in <module>
# ----> 1 data["revenue"] = data[data.num_subscribers * data.price]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# year                                 int64
# dtype: object
